# %% [markdown]
# # 판다스
#
# 판다스(Pandas)는 파이썬에서 데이터 분석과 처리에 가장 널리 사용되는 라이브러리입니다. 다양한 파일 형식(CSV, Excel 등)에서 데이터를 읽고 쓸 수 있으며, 강력한 데이터프레임(DataFrame)과 시리즈(Series) 객체를 제공합니다.
#
# - 데이터프레임(DataFrame)은 엑셀의 테이블(Table)과 비슷한 2차원 자료구조입니다.
# - 시리즈(Series)는 데이터프레임의 한 컬럼(Column)에 해당하는 1차원 자료구조입니다.
# - 인덱스(Index)는 각 행(Row)을 구분하는 라벨 역할을 합니다.
#
# 정형 데이터(표 형태 데이터) 분석, 전처리, 통계, 시각화 등 다양한 데이터 작업에 필수적으로 사용됩니다.
#
# pandas 공식 문서: https://pandas.pydata.org/docs/user_guide/index.html#user-guide

# %%
import pandas as pd  # 판다스 라이브러리 불러오기
import numpy as np  # 넘파이 라이브러리 불러오기

list_data = [1, 2, 3, 4, 5]  # 파이썬 리스트 생성
list_name = ['a', 'b', 'c', 'd', 'e']  # 인덱스 역할을 할 리스트 생성
series = pd.Series(data = list_data, index = list_name)  # 시리즈 객체 생성 (데이터와 인덱스 지정)
print(series)  # 시리즈 출력
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
print(series.index)  # 시리즈의 인덱스 객체 출력
print(series.values)  # 시리즈의 값(데이터) 출력
print(series.dtype)  # 시리즈의 데이터 타입 출력
type(series.values)  # 시리즈 값의 자료형(타입) 확인
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# [1 2 3 4 5]
# int64
# numpy.ndarray

# %%
series.name = 'number'  # 시리즈(Series)에 이름 지정
series.index.name = 'id'  # 인덱스(Index)에 이름 지정
print(series)  # 시리즈 출력
# Out:
# id
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: number, dtype: int64

# %%
# 딕셔너리 형태로 시리즈(Series) 생성 예시
dict_data = {
  'a': 1,
  'b': 2,
  'c': 3,
  'd': 4,
  'e': 5
}

example_obj = pd.Series(dict_data, dtype = np.float32, name = 'example_data')  # 딕셔너리로 시리즈 객체 생성
print(example_obj)  # 시리즈 출력
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# Name: example_data, dtype: float32

# %%
dict_data_1 = {"a":1, "b":2, "c":3, "d":4, "e":5}
indexes = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
series_obj_1 = pd.Series(dict_data_1, index = indexes)  # 딕셔너리로 시리즈 객체 생성 (인덱스 지정)
print(series_obj_1)  # 시리즈 출력
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# f    NaN
# g    NaN
# h    NaN
# dtype: float64

# %%
data_url = 'https://url.kr/vc7b8x'
df_data = pd.read_csv(data_url, sep= r'\s+', header= None)
df_data.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']# CSV 파일을 데이터프레임으로 불러오기
df_data.head()  # 데이터프레임의 처음 5행 출력
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Python\python313\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File c:\Python\python313\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Python\python313\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Python\python313\Lib\http\client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Python\python313\Lib\http\client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File c:\Python\python313\Lib\http\client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File c:\Python\python313\Lib\http\client.py:1479, in HTTPSConnection.connect(self)
#    1477     server_hostname = self.host
# -> 1479 self.sock = self._context.wrap_socket(self.sock,
#    1480                                       server_hostname=server_hostname)
#
# File c:\Python\python313\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File c:\Python\python313\Lib\ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#
# File c:\Python\python313\Lib\ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1032)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 data_url = 'https://url.kr/vc7b8x'
# ----> 2 df_data = pd.read_csv(data_url, sep= r'\s+', header= None)
#       3 df_data.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']# CSV 파일을 데이터프레임으로 불러오기
#       4 df_data.head()  # 데이터프레임의 처음 5행 출력
#
# File c:\Python\python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Python\python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Python\python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python\python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Python\python313\Lib\site-packages\pandas\io\common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File c:\Python\python313\Lib\site-packages\pandas\io\common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File c:\Python\python313\Lib\site-packages\pandas\io\common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Python\python313\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File c:\Python\python313\Lib\urllib\request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File c:\Python\python313\Lib\urllib\request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File c:\Python\python313\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File c:\Python\python313\Lib\urllib\request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File c:\Python\python313\Lib\urllib\request.py:1322, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1319         h.request(req.get_method(), req.selector, req.data, headers,
#    1320                   encode_chunked=req.has_header('Transfer-encoding'))
#    1321     except OSError as err: # timeout error
# -> 1322         raise URLError(err)
#    1323     r = h.getresponse()
#    1324 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1032)>

# %%
import pandas as pd  # 판다스 라이브러리 불러오기

# 현재 디렉터리에 있는 house.csv 파일을 데이터프레임으로 읽기
house_df = pd.read_csv('house.csv')

# 데이터프레임의 상위 5개 행 출력
print(house_df.head())
# Out:
#   0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0   0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1   0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2   0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3   0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4   0.02985   0.00   2.180  0  0.4580  6.4300  58...

# %%
from pandas import DataFrame, Series  # 판다스의 DataFrame 클래스 불러오기

raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'age': [42, 52, 36, 24, 73],
            'city': ['San Francisco', 'Baltimore', 'Miami', 'Douglas', 'Boston']}

df = pd.DataFrame(raw_data, columns= ['first_name', 'last_name', 'age', 'city'])  # 데이터프레임 생성
df
# Out:
#   first_name last_name  age           city
# 0      Jason    Miller   42  San Francisco
# 1      Molly  Jacobson   52      Baltimore
# 2       Tina       Ali   36          Miami
# 3       Jake    Milner   24        Douglas
# 4        Amy     Cooze   73         Boston

# %%
df2= pd.DataFrame(raw_data,
                  columns= ['first_name', 'last_name', 'age', 'city', 'debt'])# 'debt' 열 추가

df2
# Out:
#   first_name last_name  age           city debt
# 0      Jason    Miller   42  San Francisco  NaN
# 1      Molly  Jacobson   52      Baltimore  NaN
# 2       Tina       Ali   36          Miami  NaN
# 3       Jake    Milner   24        Douglas  NaN
# 4        Amy     Cooze   73         Boston  NaN

# %%
df2.info()  # 데이터프레임의 정보 출력
df2.describe()  # 데이터프레임의 기초 통계량 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  5 non-null      object
#  1   last_name   5 non-null      object
#  2   age         5 non-null      int64
#  3   city        5 non-null      object
#  4   debt        0 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes
#              age
# count   5.000000
# mean   45.400000
# std    18.460769
# min    24.000000
# 25%    36.000000
# 50%    42.000000
# 75%    52.000000
# max    73.000000

# %% [markdown]
# ## 데이터 추출

# %%
df = pd.read_excel('excel-comp-data.xlsx')  # 엑셀 파일을 데이터프레임으로 불러오기
df.head()  # 데이터프레임의 처음 5행 출력
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df.info()  # 데이터프레임의 요약 정보 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   account      15 non-null     int64
#  1   name         15 non-null     object
#  2   street       15 non-null     object
#  3   city         15 non-null     object
#  4   state        15 non-null     object
#  5   postal-code  15 non-null     int64
#  6   Jan          15 non-null     int64
#  7   Feb          15 non-null     int64
#  8   Mar          15 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.2+ KB

# %%
df.head(2)  # 데이터프레임의 처음 2행 출력
# Out:
#    account                        name              street           city  \
# 0   211829  Kerluke, Koepp and Hilpert  34456 Sean Highway     New Jaycob
# 1   320563              Walter-Trantow   1311 Alvis Tunnel  Port Khadijah
#
#            state  postal-code    Jan    Feb    Mar
# 0          Texas        28752  10000  62000  35000
# 1  NorthCarolina        38365  95000  45000  35000

# %%
df.tail(3)  # 데이터프레임의 마지막 3행 출력
# Out:
#     account                          name                 street  \
# 12   242368  Frami, Anderson and Donnelly        182 Bertie Road
# 13   268755                   Walsh-Haley   2624 Beatty Parkways
# 14   273274                 McDermott PLC  8917 Bergstrom Meadow
#
#                city        state  postal-code     Jan     Feb    Mar
# 12      East Davian         Iowa        72686  162000  120000  35000
# 13     Goodwinmouth  RhodeIsland        31919   55000  120000  35000
# 14  Kathryneborough     Delaware        27933  150000  120000  70000

# %%
df.head(3).T # 데이터프레임의 처음 3행을 전치(행과 열 바꿈)하여 출력 (= df.head(3).transpose())
# Out:
#                                       0                  1  \
# account                          211829             320563
# name         Kerluke, Koepp and Hilpert     Walter-Trantow
# street               34456 Sean Highway  1311 Alvis Tunnel
# city                         New Jaycob      Port Khadijah
# state                             Texas      NorthCarolina
# postal-code                       28752              38365
# Jan                               10000              95000
# Feb                               62000              45000
# Mar                               35000              35000
#
#                                                 2
# account                                    648336
# name                   Bashirian, Kunde and Price
# street       62184 Schamberger Underpass Apt. 231
# city                               New Lilianland
# state                                        Iowa
# postal-code                                 76517
# Jan                                         91000
# Feb                                        120000
# Mar                                         35000

# %%
df[["account", "street", "state"]].head(3)
# Out:
#    account                                street          state
# 0   211829                    34456 Sean Highway          Texas
# 1   320563                     1311 Alvis Tunnel  NorthCarolina
# 2   648336  62184 Schamberger Underpass Apt. 231           Iowa

# %%
df[:3]
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %%
df[["name", "street"]][:4]  # 처음 4행의 name, street 열 출력
# Out:
#                           name                                street
# 0   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1               Walter-Trantow                     1311 Alvis Tunnel
# 2   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144

# %%
df.index = df["account"]  # account 열을 인덱스로 지정
df.head()
# Out:
#          account                         name  \
# account
# 211829    211829   Kerluke, Koepp and Hilpert
# 320563    320563               Walter-Trantow
# 648336    648336   Bashirian, Kunde and Price
# 109996    109996  D'Amore, Gleichner and Bode
# 121213    121213                Bauch-Goldner
#
#                                        street             city          state  \
# account
# 211829                     34456 Sean Highway       New Jaycob          Texas
# 320563                      1311 Alvis Tunnel    Port Khadijah  NorthCarolina
# 648336   62184 Schamberger Underpass Apt. 231   New Lilianland           Iowa
# 109996            155 Fadel Crescent Apt. 144       Hyattburgh          Maine
# 121213                    7274 Marissa Common  Shanahanchester     California
#
#          postal-code     Jan     Feb    Mar
# account
# 211829         28752   10000   62000  35000
# 320563         38365   95000   45000  35000
# 648336         76517   91000  120000  35000
# 109996         46021   45000  120000  10000
# 121213         49681  162000  120000  35000

# %%
# del df["account"]   # account 열 삭제
df.head()
# Out:
#                                 name                                street  \
# account
# 211829    Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 320563                Walter-Trantow                     1311 Alvis Tunnel
# 648336    Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 109996   D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 121213                 Bauch-Goldner                   7274 Marissa Common
#
#                     city          state  postal-code     Jan     Feb    Mar
# account
# 211829        New Jaycob          Texas        28752   10000   62000  35000
# 320563     Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 648336    New Lilianland           Iowa        76517   91000  120000  35000
# 109996        Hyattburgh          Maine        46021   45000  120000  10000
# 121213   Shanahanchester     California        49681  162000  120000  35000

# %%
df.loc[[211829, 109996],["name", "street"]]   # account가 211829, 109996인 행의 name, street 열 출력
# Out:
#                                 name                       street
# account
# 211829    Kerluke, Koepp and Hilpert           34456 Sean Highway
# 109996   D'Amore, Gleichner and Bode  155 Fadel Crescent Apt. 144

# %%
df.loc[205217:,["name", "city"]]  # account가 205217 이상인 행의 name, city 열 출력
# Out:
#                                  name             city
# account
# 205217               Kovacek-Johnston       Deronville
# 209744                 Champlin-Morar  Lake Juliannton
# 212303                 Gerhold-Maggio        North Ras
# 214098    Goodwin, Homenick and Jerde         Rosaberg
# 231907                     Hahn-Moore    Norbertomouth
# 242368   Frami, Anderson and Donnelly      East Davian
# 268755                    Walsh-Haley     Goodwinmouth
# 273274                  McDermott PLC  Kathryneborough

# %%
df.iloc[[1, 2]][["name", "street"]] # 1, 2번째 행의 name, street 열 출력
# Out:
#                                name                                street
# account
# 320563               Walter-Trantow                     1311 Alvis Tunnel
# 648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231

# %%
df.iloc[:10, :3]  # 처음 10행의 처음 3열 출력 (= df.iloc[0:10][["name", "street", "city"]])
# Out:
#                                      name  \
# account
# 211829         Kerluke, Koepp and Hilpert
# 320563                     Walter-Trantow
# 648336         Bashirian, Kunde and Price
# 109996        D'Amore, Gleichner and Bode
# 121213                      Bauch-Goldner
# 132971   Williamson, Schumm and Hettinger
# 145068                         Casper LLC
# 205217                   Kovacek-Johnston
# 209744                     Champlin-Morar
# 212303                     Gerhold-Maggio
#
#                                        street               city
# account
# 211829                     34456 Sean Highway         New Jaycob
# 320563                      1311 Alvis Tunnel      Port Khadijah
# 648336   62184 Schamberger Underpass Apt. 231     New Lilianland
# 109996            155 Fadel Crescent Apt. 144         Hyattburgh
# 121213                    7274 Marissa Common    Shanahanchester
# 132971                   89403 Casimer Spring       Jeremieburgh
# 145068           340 Consuela Bridge Apt. 400  Lake Gabriellaton
# 205217           91971 Cronin Vista Suite 601         Deronville
# 209744                       26739 Grant Lock    Lake Juliannton
# 212303              366 Maggio Grove Apt. 998          North Ras

# %%
df_new = df.reset_index()  # 인덱스를 초기화하여 숫자형 인덱스로 변경
df_new.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df_new.drop(1).head()  # 인덱스 1인 행 삭제 후 처음 5행 출력

# df_new = df_new.drop(1)  # 인덱스 1인 행 삭제 후 데이터프레임에 반영
# df_new.drop(1, inplace=True)  # 인덱스 1인 행 삭제 후 데이터프레임에 반영
# Out:
#    account                              name  \
# 0   211829        Kerluke, Koepp and Hilpert
# 2   648336        Bashirian, Kunde and Price
# 3   109996       D'Amore, Gleichner and Bode
# 4   121213                     Bauch-Goldner
# 5   132971  Williamson, Schumm and Hettinger
#
#                                  street             city       state  \
# 0                    34456 Sean Highway       New Jaycob       Texas
# 2  62184 Schamberger Underpass Apt. 231   New Lilianland        Iowa
# 3           155 Fadel Crescent Apt. 144       Hyattburgh       Maine
# 4                   7274 Marissa Common  Shanahanchester  California
# 5                  89403 Casimer Spring     Jeremieburgh    Arkansas
#
#    postal-code     Jan     Feb    Mar
# 0        28752   10000   62000  35000
# 2        76517   91000  120000  35000
# 3        46021   45000  120000  10000
# 4        49681  162000  120000  35000
# 5        62785  150000  120000  35000

# %%
df_new.drop("account", axis=1).head()  # account 열 삭제 후 처음 5행 출력
# axis = 1: 열, 0: 행
# Out:
#                           name                                street  \
# 0   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1               Walter-Trantow                     1311 Alvis Tunnel
# 2   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df_new.drop(["account", "name"], axis=1).head()  # account, name 열 삭제 후 처음 5행 출력
# Out:
#                                  street             city          state  \
# 0                    34456 Sean Highway       New Jaycob          Texas
# 1                     1311 Alvis Tunnel    Port Khadijah  NorthCarolina
# 2  62184 Schamberger Underpass Apt. 231   New Lilianland           Iowa
# 3           155 Fadel Crescent Apt. 144       Hyattburgh          Maine
# 4                   7274 Marissa Common  Shanahanchester     California
#
#    postal-code     Jan     Feb    Mar
# 0        28752   10000   62000  35000
# 1        38365   95000   45000  35000
# 2        76517   91000  120000  35000
# 3        46021   45000  120000  10000
# 4        49681  162000  120000  35000

# %% [markdown]
# ## 그룹별 집계

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings', 'Kings', 'Kings', 'Riders', 'Devils', 'Riders'],
            'Rank': [1, 2, 2, 3, 3, 4, 1, 1, 2, 4],
            'Year': [2014, 2015, 2014, 2015, 2014, 2015, 2016, 2016, 2016, 2015],
            'Points': [876, 789, 863, 673, 741, 812, 756, 788, 694, 701]}

df = pd.DataFrame(ipl_data)  # 데이터프레임 생성
df
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# 4   Kings     3  2014     741
# 5   Kings     4  2015     812
# 6   Kings     1  2016     756
# 7  Riders     1  2016     788
# 8  Devils     2  2016     694
# 9  Riders     4  2015     701

# %%
df.groupby('Team')["Points"].sum()  # Team 열을 기준으로 그룹화하여 합계 계산
# Out:
# Team
# Devils    2230
# Kings     2309
# Riders    3154
# Name: Points, dtype: int64

# %%
multi_groupby = df.groupby(['Team', 'Year'])["Points"].sum()  # Team, Year 열을 기준으로 그룹화하여 Points의 합계 계산
multi_groupby.index
# Out:
# MultiIndex([('Devils', 2014),
#             ('Devils', 2015),
#             ('Devils', 2016),
#             ( 'Kings', 2014),
#             ( 'Kings', 2015),
#             ( 'Kings', 2016),
#             ('Riders', 2014),
#             ('Riders', 2015),
#             ('Riders', 2016)],
#            names=['Team', 'Year'])

# %%
multi_groupby["Devils":"Kings"] # Team이 Devils부터 Kings까지의 그룹 출력
# Out:
# Team    Year
# Devils  2014    863
#         2015    673
#         2016    694
# Kings   2014    741
#         2015    812
#         2016    756
# Name: Points, dtype: int64

# %%
multi_groupby.unstack()  # 멀티 인덱스를 단일 인덱스로 변환
# Out:
# Year    2014  2015  2016
# Team
# Devils   863   673   694
# Kings    741   812   756
# Riders   876  1490   788

# %%
multi_groupby.swaplevel().sort_index()  # 멀티 인덱스의 레벨 순서 변경 후 정렬
# Out:
# Year  Team
# 2014  Devils     863
#       Kings      741
#       Riders     876
# 2015  Devils     673
#       Kings      812
#       Riders    1490
# 2016  Devils     694
#       Kings      756
#       Riders     788
# Name: Points, dtype: int64

# %%
multi_groupby.groupby(level=0).sum()  # 첫 번째 레벨(Team) 기준으로 그룹화하여 합계 계산
# Out:
# Team
# Devils    2230
# Kings     2309
# Riders    3154
# Name: Points, dtype: int64

# %%
multi_groupby.groupby(level=1).sum()  # 두 번째 레벨(Year) 기준으로 그룹화하여 합계 계산
# Out:
# Year
# 2014    2480
# 2015    2975
# 2016    2238
# Name: Points, dtype: int64

# %%
grouped = df.groupby('Team')  # Team 열을 기준으로 그룹화
grouped.get_group('Riders')  # 'Riders' 그룹 출력
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 7  Riders     1  2016     788
# 9  Riders     4  2015     701

# %%
grouped.agg('min')
# Out:
#         Rank  Year  Points
# Team
# Devils     2  2014     673
# Kings      1  2014     741
# Riders     1  2014     701

# %%
grouped.agg(np.mean)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12128\1243003623.py:1: FutureWarning: The provided callable <function mean at 0x00000234D9D0ECA0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped.agg(np.mean)
#             Rank    Year      Points
# Team
# Devils  2.333333  2015.0  743.333333
# Kings   2.666667  2015.0  769.666667
# Riders  2.000000  2015.0  788.500000

# %%
grouped.transform('max')  # 각 그룹별로 열의 최대값을 원래 데이터프레임의 크기와 동일하게 반환
# Out:
#    Rank  Year  Points
# 0     4  2016     876
# 1     4  2016     876
# 2     3  2016     863
# 3     3  2016     863
# 4     4  2016     812
# 5     4  2016     812
# 6     4  2016     812
# 7     4  2016     876
# 8     3  2016     863
# 9     4  2016     876

# %%
score = lambda x: (x - x.mean()) / x.std()  # 점수 계산을 위한 람다 함수 정의
grouped.transform(score)  # 각 그룹별로 점수 계산 후 원래 데이터프레임의 크기와 동일하게 반환
# Out:
#        Rank      Year    Points
# 0 -0.707107 -1.224745  1.224725
# 1  0.000000  0.000000  0.006998
# 2 -0.577350 -1.000000  1.148819
# 3  1.154701  0.000000 -0.675211
# 4  0.218218 -1.000000 -0.766058
# 5  0.872872  0.000000  1.131271
# 6 -1.091089  1.000000 -0.365214
# 7 -0.707107  1.224745 -0.006998
# 8 -0.577350  1.000000 -0.473608
# 9  1.414214  0.000000 -1.224725

# %%
df.groupby('Team').filter(lambda x: len(x) >= 4)  # 각 그룹의 크기가 4 이상인 그룹만 필터링하여 반환
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 7  Riders     1  2016     788
# 9  Riders     4  2015     701

# %%
df.groupby('Team').filter(
  lambda x: x['Points'].max() > 810
)
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# 4   Kings     3  2014     741
# 5   Kings     4  2015     812
# 6   Kings     1  2016     756
# 7  Riders     1  2016     788
# 8  Devils     2  2016     694
# 9  Riders     4  2015     701

# %% [markdown]
# ## 병합과 연결

# %%
raw_data = { 'subject_id': [1, 2, 3, 4, 5, 7, 8, 9, 10, 11],
            'test_score': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

df_left = pd.DataFrame(raw_data, columns=['subject_id', 'test_Score'])  # 왼쪽 데이터프레임 생성
df_left
# Out:
#    subject_id  test_Score
# 0           1          51
# 1           2          15
# 2           3          15
# 3           4          61
# 4           5          16
# 5           7          14
# 6           8          15
# 7           9           1
# 8          10          61
# 9          11          16

# %%
raw_data = {
  'subject_id': [4, 5, 6, 7, 8],
  'first_name': ['Amy', 'Billy', 'Chuck', 'Diana', 'Eve'],
  'last_name': ['Duke', 'Doe', 'Evans', 'Smith', 'Johnson']
}

df_right = pd.DataFrame(raw_data, columns=['subject_id', 'first_name', 'last_name'])  # 오른쪽 데이터프레임 생성
df_right
# Out:
#    subject_id first_name last_name
# 0           4        Amy      Duke
# 1           5      Billy       Doe
# 2           6      Chuck     Evans
# 3           7      Diana     Smith
# 4           8        Eve   Johnson

# %%
pd.merge(df_left, df_right, on='subject_id', how='inner')  # 내부 조인
# df_left.merge(df_right, on='subject_id', how='inner')
# Out:
#    subject_id  test_Score first_name last_name
# 0           4          61        Amy      Duke
# 1           5          16      Billy       Doe
# 2           7          14      Diana     Smith
# 3           8          15        Eve   Johnson

# %%
import os
os.listdir()  # 현재 디렉터리의 파일 및 폴더 목록 출력
# Out:
# ['.git',
#  '0.변수,자료형,내장함수.ipynb',
#  '1.리스트,튜플,딕셔너리.ipynb',
#  '2.제어문.ipynb',
#  '3.함수.ipynb',
#  '4.파이썬 고급(클래스,모듈,예외처리).ipynb',
#  '5.판다스.ipynb',
#  'excel-comp-data.xlsx',
#  'house.csv',
#  'mod.py',
#  'mod1.py',
#  'move.xlsx',
#  'sales-feb-2014.xlsx',
#  'sales-jan-2014.xlsx',
#  'sales-mar-2014.xlsx',
#  'test.py',
#  '__pycache__',
#  '인구소멸지역_데이터분석.ipynb']

# %%
fileNames = [os.path.join(os.getcwd(), fileName) for fileName in os.listdir() if 'sales' in fileName]

print(fileNames)  # 'sales'가 포함된 파일 경로 출력
# Out:
# ['c:\\Users\\Admin\\AWS Korea_sesac\\sales-feb-2014.xlsx', 'c:\\Users\\Admin\\AWS Korea_sesac\\sales-jan-2014.xlsx', 'c:\\Users\\Admin\\AWS Korea_sesac\\sales-mar-2014.xlsx']

# %%
df_list = [pd.read_excel(fileName) for fileName in fileNames]
for df in df_list:
  print(type(df), len(df))
# Out:
# <class 'pandas.core.frame.DataFrame'> 108
# <class 'pandas.core.frame.DataFrame'> 134
# <class 'pandas.core.frame.DataFrame'> 142

# %%
df = pd.concat(df_list, axis=0) # 데이터프레임 리스트를 하나로 연결
print(len(df))
df.reset_index(drop=True)  # 인덱스 재설정
# Out:
# 384
#      account number                          name       sku  quantity  \
# 0            383080                      Will LLC  B1-20000         7
# 1            412290                 Jerde-Hilpert  S1-27722        11
# 2            412290                 Jerde-Hilpert  B1-86481         3
# 3            412290                 Jerde-Hilpert  B1-20000        23
# 4            672390               Kuhn-Gusikowski  S1-06532        48
# ..              ...                           ...       ...       ...
# 379          737550  Fritsch, Russel and Anderson  B1-65551        12
# 380          642753                   Pollich LLC  S1-93683        21
# 381          412290                 Jerde-Hilpert  B1-20000        30
# 382          307599   Kassulke, Ondricka and Metz  S2-16558        46
# 383          672390               Kuhn-Gusikowski  B1-04202        19
#
#      unit price  ext price                 date
# 0         33.69     235.83  2014-02-01 09:04:59
# 1         21.12     232.32  2014-02-01 11:51:46
# 2         35.99     107.97  2014-02-01 17:24:32
# 3         78.90    1814.70  2014-02-01 19:56:48
# 4         55.82    2679.36  2014-02-02 03:45:20
# ..          ...        ...                  ...
# 379       56.24     674.88  2014-03-31 08:43:24
# 380       92.57    1943.97  2014-03-31 11:37:34
# 381       22.38     671.40  2014-03-31 21:41:31
# 382       56.04    2577.84  2014-03-31 22:11:22
# 383       27.86     529.34  2014-03-31 23:13:14
#
# [384 rows x 7 columns]

# %%
df_1 = pd.read_excel('sales-feb-2014.xlsx')
df_2 = pd.read_excel('sales-jan-2014.xlsx')
df_3 = pd.read_excel('sales-mar-2014.xlsx')

df = pd.concat([df_1, df_2, df_3], axis=0) #  데이터프레임 리스트를 행 방향(아래로) 하나로 연결
df.reset_index(drop=True, inplace=True) # 인덱스를 0부터 다시 부여하며, 기존 인덱스는 버리고 원본 데이터프레임에 바로 반영
                                        #   - drop=True : 기존 인덱스를 새로운 열로 남기지 않고 완전히 삭제
                                        #   - inplace=True : 결과를 새로운 객체로 반환하지 않고, 원본 데이터프레임을 직접 변경
df
# Out:
#      account number                          name       sku  quantity  \
# 0            383080                      Will LLC  B1-20000         7
# 1            412290                 Jerde-Hilpert  S1-27722        11
# 2            412290                 Jerde-Hilpert  B1-86481         3
# 3            412290                 Jerde-Hilpert  B1-20000        23
# 4            672390               Kuhn-Gusikowski  S1-06532        48
# ..              ...                           ...       ...       ...
# 379          737550  Fritsch, Russel and Anderson  B1-65551        12
# 380          642753                   Pollich LLC  S1-93683        21
# 381          412290                 Jerde-Hilpert  B1-20000        30
# 382          307599   Kassulke, Ondricka and Metz  S2-16558        46
# 383          672390               Kuhn-Gusikowski  B1-04202        19
#
#      unit price  ext price                 date
# 0         33.69     235.83  2014-02-01 09:04:59
# 1         21.12     232.32  2014-02-01 11:51:46
# 2         35.99     107.97  2014-02-01 17:24:32
# 3         78.90    1814.70  2014-02-01 19:56:48
# 4         55.82    2679.36  2014-02-02 03:45:20
# ..          ...        ...                  ...
# 379       56.24     674.88  2014-03-31 08:43:24
# 380       92.57    1943.97  2014-03-31 11:37:34
# 381       22.38     671.40  2014-03-31 21:41:31
# 382       56.04    2577.84  2014-03-31 22:11:22
# 383       27.86     529.34  2014-03-31 23:13:14
#
# [384 rows x 7 columns]

# %%
df.to_csv('total_sales.csv')  # 데이터프레임을 CSV 파일로 저장 (인덱스 제외)
